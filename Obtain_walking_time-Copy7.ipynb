# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }  </style>

# %%
df_stops = pd.read_csv("stops.csv")

# %%
df_stopsPlus = pd.read_csv('042916_stops_close_stops_frequency.csv')

# %%
df_Mat = pd.read_csv("output_3-1-2016.csv")

# %%
df_67k = pd.read_csv("67k_address.csv")

# %%
df_340k = pd.read_csv("052316_stop_addr_340k.csv")
# Out:
# //anaconda/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_81k = pd.read_csv("052316_81k_all_Cleveland_walking_time.csv")

# %%
df_300k = pd.read_csv('300K_spots_address.csv')

# %%
import seaborn as sns

# %%
df_115k = pd.read_csv("115k_addr.csv")

# %%
df_192k = pd.read_csv('192k_addr.csv')

# %%
df_340k = pd.read_csv("052316_stop_addr_340k.csv")
# Out:
# //anaconda/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# #  Plot close up

# %%
plt.scatter(df_192k.addr_lon, df_192k.addr_lat)
plt.xlim(-81.8,-81.75)
plt.ylim(41.4,41.45)
# Out:
# (41.4, 41.45)

# %%
plt.scatter(df_81k.addr_lon, df_81k.addr_lat)
plt.xlim(-81.8,-81.75)
plt.ylim(41.4,41.45)
# Out:
# (41.4, 41.45)

# %%
plt.scatter(df_340k.addr_lon, df_340k.addr_lat)
plt.xlim(-81.8,-81.75)
plt.ylim(41.4,41.45)
# Out:
# (41.4, 41.45)

# %%
plt.scatter(df.addr_lon, df.addr_lat)
plt.xlim(-81.8,-81.75)
plt.ylim(41.4,41.45)
# Out:
# (41.4, 41.45)

# %%
df_340k_g = pd.read_csv('grouped340k.csv')

# %%
df_340k_gmin= df_340k_g[df_340k_g["Unnamed: 2"]=='min']

# %%
plt.scatter(df_340k_gmin.addr_lon, df_340k_gmin.addr_lat)
plt.xlim(-81.8,-81.75)
plt.ylim(41.4,41.45)
# Out:
# (41.4, 41.45)

# %%
df_340k_gmin = df_340k_gmin[['addr_lat','addr_lon','walking_time']]

# %%
plt.scatter(df_340k_gmin.addr_lon, df_340k_gmin.addr_lat)

# %%
df_Mat.head()
# Out:
#    Unnamed: 0  address_latitude  address_longitude  stop_latitude  \
# 0           0         41.427883             -81.66      41.446877
# 1           1         41.427883             -81.66      41.447112
# 2           2         41.427883             -81.66      41.446992
# 3           3         41.427883             -81.66      41.446953
# 4           4         41.427883             -81.66      41.447113
#
#    stop_longitude  distance  time
# 0      -81.658588      2425  1748
# 1      -81.659555      2505  1806
# 2      -81.662701      2768  1996
# 3      -81.657015      2295  1654
# 4      -81.657469      2330  1680

# %%
df_mat_g = pd.read_csv("matgroup.csv")

# %%
df_mat_g[df_mat_g['Unnamed: 2']=='min'].describe()
# Out:
#            addr_lat      addr_lon     Unnamed: 0      distance  stop_latitude  \
# count  26313.000000  26313.000000   26313.000000  26313.000000   26313.000000
# mean      41.478983    -81.579900   65780.000000    417.846958      41.477808
# std        0.029705      0.046506   37980.265764    449.591117       0.029328
# min       41.427883    -81.660000       0.000000      0.000000      41.408959
# 25%       41.453083    -81.620400   32890.000000    146.000000      41.450317
# 50%       41.478983    -81.579900   65780.000000    292.000000      41.477818
# 75%       41.504883    -81.539400   98670.000000    511.000000      41.501282
# max       41.530083    -81.499800  131560.000000   3992.000000      41.538847
#
#        stop_longitude  walking_time
# count    26313.000000  26313.000000
# mean       -81.581661    301.374302
# std          0.046334    324.094969
# min        -81.665767      0.000000
# 25%        -81.621443    106.000000
# 50%        -81.582026    211.000000
# ...

# %%
df_mat_gmin = df_mat_g[df_mat_g['Unnamed: 2']=='min']

# %%
df_mat_gmin = df_mat_gmin[['addr_lat','addr_lon','walking_time']]

# %%
df = pd.concat([df_340k_gmin, df_mat_gmin])

# %%
df.describe()
# Out:
#            addr_lat      addr_lon  walking_time
# count  94119.000000  94119.000000  94119.000000
# mean      41.450145    -81.666304    396.788916
# std        0.071786      0.139498    451.996726
# min       41.221000    -81.974000      0.000000
# 25%       41.404000    -81.780000    128.000000
# 50%       41.454000    -81.637000    270.000000
# 75%       41.495783    -81.547500    491.000000
# max       41.644000    -81.432000   6796.000000

# %%
plt.scatter(df.addr_lon, df.addr_lat)
plt.xlim(-81.8,-81.75)
plt.ylim(41.4,41.45)
# Out:
# (41.4, 41.45)

# %%
plt.scatter(df.addr_lon, df.addr_lat, c = 6-df.walking_time/1000)
plt.xlim(-81.8,-81.75)
plt.ylim(41.4,41.45)
# Out:
# (41.4, 41.45)

# %%
plt.scatter(df.addr_lon, df.addr_lat, c = df.walking_time, alpha=0.1)

# %%
df.head()
# Out:
#     addr_lat  addr_lon  walking_time
# 3     41.221   -81.848         578.0
# 11    41.221   -81.847         484.0
# 19    41.221   -81.846         484.0
# 27    41.221   -81.845         555.0
# 35    41.221   -81.844         554.0

# %%
df.to_csv('052816_94k_addr.csv', index = False)

# %%
df = df.sort_values(['addr_lat','addr_lon'])

# %%
df = pd.read_csv('052816_94k_addr.csv')

# %%
plt.scatter(df.addr_lon, df.addr_lat, c = 6-df.walking_time/1000)
plt.xlim(-81.8,-81.75)
plt.ylim(41.4,41.45)
# Out:
# (41.4, 41.45)

# %%
plt.scatter(df.addr_lon, df.addr_lat, c = (7-df.walking_time/1000)/10, alpha = 0.01)

# %%
df_collection2 = df_collection[df_collection.addr_lat > 41.3]

# %%
plt.scatter(df_collection2.addr_lon, df_collection2.addr_lat)

# %%
df_collection2.describe()
# Out:
#           Unnamed: 0       addr_lat       addr_lon  surrounding_stops  \
# count  136034.000000  136034.000000  136034.000000      136034.000000
# mean   163661.007432      41.428428     -81.673135           9.654101
# std     80176.353260       0.080458       0.160305          12.326464
# min      9601.000000      41.301000     -81.981000           0.000000
# 25%     95221.250000      41.362000     -81.810000           0.000000
# 50%    174689.500000      41.423000     -81.651000           6.000000
# 75%    234160.750000      41.485000     -81.532000          16.000000
# max    287865.000000      41.650000     -81.425000         139.000000
#
#        surrounding_stops_a_mile
# count             136034.000000
# mean                  38.587441
# std                   39.922378
# min                    0.000000
# 25%                    5.000000
# 50%                   26.000000
# 75%                   62.000000
# max                  257.000000

# %%
df_collection2[df_collection2.surrounding_stops_a_mile == 0].describe()
# Out:
#           Unnamed: 0      addr_lat      addr_lon  surrounding_stops  \
# count   27118.000000  27118.000000  27118.000000            27118.0
# mean   168656.630135     41.360318    -81.663007                0.0
# std     98236.301667      0.061055      0.196438                0.0
# min      9601.000000     41.301000    -81.981000                0.0
# 25%     58166.250000     41.320000    -81.884000                0.0
# 50%    203669.500000     41.338000    -81.593000                0.0
# 75%    263378.750000     41.375000    -81.474000                0.0
# max    287804.000000     41.622000    -81.425000                0.0
#
#        surrounding_stops_a_mile
# count                   27118.0
# mean                        0.0
# std                         0.0
# min                         0.0
# 25%                         0.0
# 50%                         0.0
# 75%                         0.0
# max                         0.0

# %%
df_tobecollected = df_collection2[df_collection2.surrounding_stops_a_mile == 0]

# %%
df_tobecollected.to_csv('points_to_be_calc.csv', index = False)

# %%
df_tobecollected = pd.read_csv('points_to_be_calc.csv')

# %%
df = df_stopsPlus.head(0)
df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, stop_id, stop_code, stop_name, stop_desc, stop_lat, stop_lon, zone_id, stop_url, location_type, parent_station, total_bus_frequency, close_stops]
# Index: []

# %%
search_range = 0.007225*3

for i in range(len(df_tobecollected)):
    
    search_range = 0.007225*3
    df_temp = dataframe_of_close_stops(df_tobecollected.loc[i, 'addr_lat'],df_tobecollected.loc[i, 'addr_lon'],df_stopsPlus, search_range)
    if len(df_temp)<5:
        while len(df_temp)<5:
            search_range = search_range * 2
            df_temp = dataframe_of_close_stops(df_tobecollected.loc[i, 'addr_lat'],df_tobecollected.loc[i, 'addr_lon'],df_stopsPlus, search_range)
    
    df_temp = Add_distance_to_dataframe(df_temp,df_tobecollected.loc[i, 'addr_lat'],df_tobecollected.loc[i, 'addr_lon'] )
    df_temp = df_temp.sort_values("distance").head(5)
    df_temp['addr_lat']= df_tobecollected.loc[i, 'addr_lat']
    df_temp['addr_lon']= df_tobecollected.loc[i, 'addr_lon']
    df = pd.concat([df, df_temp])
    
    if i%1000 == 0:
        print(i)
# Out:
# //anaconda/lib/python3.4/site-packages/pandas/core/indexing.py:284: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# //anaconda/lib/python3.4/site-packages/pandas/core/indexing.py:461: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000

# %%
df.head()
# Out:
#      Unnamed: 0  Unnamed: 0.1  addr_lat  addr_lon  close_stops  distance  \
# 211        4878          4878    41.301   -81.981          1.0  4.456469
# 210        4877          4877    41.301   -81.981          1.0  4.612756
# 212        4879          4879    41.301   -81.981          1.0  4.660325
# 209        4876          4876    41.301   -81.981          1.0  4.765409
# 213        4880          4880    41.301   -81.981          1.0  4.822150
#
#      location_type parent_station  stop_code  stop_desc stop_id   stop_lat  \
# 211            0.0            NaN        NaN        NaN   10118  41.350930
# 210            0.0            NaN        NaN        NaN   10117  41.350921
# 212            0.0            NaN        NaN        NaN   10119  41.353926
# 209            0.0            NaN        NaN        NaN   10116  41.350796
# 213            0.0            NaN        NaN        NaN   10120  41.355799
#
#       stop_lon                                   stop_name  stop_url  \
# ...

# %%
df.to_csv('data_to_be_collected_plus_stops.csv', index = False)

# %%
df.describe()
# Out:
#           Unnamed: 0   Unnamed: 0.1       addr_lat       addr_lon  \
# count  136170.000000  136170.000000  136170.000000  136170.000000
# mean     3954.600962    3954.600962      41.360149     -81.664362
# std      1919.071106    1919.071106       0.060984       0.197107
# min        23.000000      23.000000      41.301000     -81.981000
# 25%      3069.000000    3069.000000      41.320000     -81.885000
# 50%      4711.000000    4711.000000      41.338000     -81.593000
# 75%      5176.000000    5176.000000      41.375000     -81.474000
# max      6432.000000    6432.000000      41.622000     -81.425000
#
#          close_stops       distance  location_type  stop_code  stop_desc  \
# count  136170.000000  136170.000000  136170.000000        0.0        0.0
# mean        1.408034       1.965571       0.000720        NaN        NaN
# std         0.491546       0.828763       0.026817        NaN        NaN
# min         1.000000       0.753873       0.000000        NaN        NaN
# ...

# %%
df = pd.read_csv('data_to_be_collected_plus_stops.csv')
# Out:
# //anaconda/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
i = 0
df.loc[i, "walking_time"] = getWalkingTime(df.loc[i,"stop_lat"],df.loc[i,"stop_lon"],df.loc[i,"addr_lat"],df.loc[i,"addr_lon"])

# %%
i = 0
df.loc[i,"stop_lat"]
# Out:
# 41.350929999999998

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  addr_lat  addr_lon  close_stops  distance  \
# 0        4878          4878    41.301   -81.981          1.0  4.456469
# 1        4877          4877    41.301   -81.981          1.0  4.612756
# 2        4879          4879    41.301   -81.981          1.0  4.660325
# 3        4876          4876    41.301   -81.981          1.0  4.765409
# 4        4880          4880    41.301   -81.981          1.0  4.822150
#
#    location_type parent_station  stop_code  stop_desc stop_id   stop_lat  \
# 0            0.0            NaN        NaN        NaN   10118  41.350930
# 1            0.0            NaN        NaN        NaN   10117  41.350921
# 2            0.0            NaN        NaN        NaN   10119  41.353926
# 3            0.0            NaN        NaN        NaN   10116  41.350796
# 4            0.0            NaN        NaN        NaN   10120  41.355799
#
#     stop_lon                                   stop_name  stop_url  \
# ...

# %%
for i in range (len(df)):
     
    if np.isnan(df.loc[i, "walking_time"]):
        df.loc[i, "walking_time"] = getWalkingTime(df.loc[i,"stop_lat"],df.loc[i,"stop_lon"],df.loc[i,"addr_lat"],df.loc[i,"addr_lon"])
    
        if i%10000 == 0:
            num = str(int(i/1000))
            df.to_csv("stop_addr_rest_{}k.csv".format(num), index = False)



               
            
    if i%1000 == 0:
        print(i)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# ...

# %%
df.to_csv('missing_stop_136k.csv', index = False)

# %%
plt.scatter(df.addr_lon, df.addr_lat)

# %%
df_340k.head()
# Out:
#   stop_id                                  stop_name   stop_lat   stop_lon  \
# 0   10197  LORAIN RD & NORTH OLMSTED INDUSTRIAL PKWY  41.391666 -81.967530
# 1   10015  LORAIN RD & NORTH OLMSTED INDUSTRIAL PKWY  41.391715 -81.967442
# 2   09983                            31255 LORAIN RD  41.392709 -81.966235
# 3   09033                            31276 LORAIN RD  41.392850 -81.966416
# 4   09031         NORTH OLMSTED INDUSTRIAL PKWY LOOP  41.390873 -81.960973
#
#    location_type  total_bus_frequency  close_stops  distance  addr_lat  \
# 0            0.0                170.0          2.0  0.569814    41.385
# 1            0.0                168.0          2.0  0.575245    41.385
# 2            0.0                168.0          2.0  0.667742    41.385
# 3            0.0                170.0          2.0  0.669943    41.385
# 4            0.0                338.0          1.0  0.789075    41.385
#
#    addr_lon  walking_time
# 0   -81.974         985.0
# 1   -81.974         985.0
# ...

# %%
df_136k = pd.read_csv("missing_stop_136k.csv")
# Out:
# //anaconda/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_136k = df_136k.drop('Unnamed: 0.1',1)

# %%
df_136k.head()
# Out:
#    addr_lat  addr_lon  close_stops  distance  location_type parent_station  \
# 0    41.301   -81.981          1.0  4.456469            0.0            NaN
# 1    41.301   -81.981          1.0  4.612756            0.0            NaN
# 2    41.301   -81.981          1.0  4.660325            0.0            NaN
# 3    41.301   -81.981          1.0  4.765409            0.0            NaN
# 4    41.301   -81.981          1.0  4.822150            0.0            NaN
#
#    stop_code  stop_desc stop_id   stop_lat   stop_lon  \
# 0        NaN        NaN   10118  41.350930 -81.926671
# 1        NaN        NaN   10117  41.350921 -81.922034
# 2        NaN        NaN   10119  41.353926 -81.925356
# 3        NaN        NaN   10116  41.350796 -81.917534
# 4        NaN        NaN   10120  41.355799 -81.923482
#
#                                     stop_name  stop_url  total_bus_frequency  \
# 0              W SPRAGUE RD & USHER RD (FLAG)       NaN                  4.0
# ...

# %%
df_total = pd.concat([df_340k, df_136k])

# %%
df_total.head()
# Out:
#    addr_lat  addr_lon  close_stops  distance  location_type parent_station  \
# 0    41.385   -81.974          2.0  0.569814            0.0            NaN
# 1    41.385   -81.974          2.0  0.575245            0.0            NaN
# 2    41.385   -81.974          2.0  0.667742            0.0            NaN
# 3    41.385   -81.974          2.0  0.669943            0.0            NaN
# 4    41.385   -81.974          1.0  0.789075            0.0            NaN
#
#    stop_code  stop_desc stop_id   stop_lat   stop_lon  \
# 0        NaN        NaN   10197  41.391666 -81.967530
# 1        NaN        NaN   10015  41.391715 -81.967442
# 2        NaN        NaN   09983  41.392709 -81.966235
# 3        NaN        NaN   09033  41.392850 -81.966416
# 4        NaN        NaN   09031  41.390873 -81.960973
#
#                                    stop_name  stop_url  total_bus_frequency  \
# 0  LORAIN RD & NORTH OLMSTED INDUSTRIAL PKWY       NaN                170.0
# ...

# %%
plt.scatter(df_total.addr_lon, df_total.addr_lat)
plt.xlim(-81.8,-81.75)
plt.ylim(41.4,41.45)
# Out:
# (41.4, 41.45)

# %%
plt.scatter(df_136k.addr_lon, df_136k.addr_lat)
plt.xlim(-81.8,-81.75)
plt.ylim(41.4,41.45)
# Out:
# (41.4, 41.45)

# %%
plt.scatter(df_300k_new.addr_lon, df_300k_new.addr_lat)
plt.xlim(-81.8,-81.75)
plt.ylim(41.4,41.45)
# Out:
# (41.4, 41.45)

# %%
df_300k_new = pd.read_csv("new300k.csv")

# %%
df_300k_new.head()
# Out:
#    Unnamed: 0  addr_lat  addr_lon  surrounding_stops  surrounding_stops_a_mile
# 0           0    41.200     -82.0                0.0                       0.0
# 1           1    41.201     -82.0                0.0                       0.0
# 2           2    41.202     -82.0                0.0                       0.0
# 3           3    41.203     -82.0                0.0                       0.0
# 4           4    41.204     -82.0                0.0                       0.0

# %%
df2 = df_300k_new[(df_300k_new.surrounding_stops == 0) & (df_300k_new.surrounding_stops_a_mile != 0)]

# %%
plt.scatter(df2.addr_lon, df2.addr_lat)
plt.xlim(-81.8,-81.75)
plt.ylim(41.4,41.45)
# Out:
# (41.4, 41.45)

# %%
df2.head()
# Out:
#       Unnamed: 0  addr_lat  addr_lon  surrounding_stops  \
# 9678        9678    41.378   -81.981                0.0
# 9679        9679    41.379   -81.981                0.0
# 9680        9680    41.380   -81.981                0.0
# 9681        9681    41.381   -81.981                0.0
# 9682        9682    41.382   -81.981                0.0
#
#       surrounding_stops_a_mile
# 9678                       2.0
# 9679                       2.0
# 9680                       2.0
# 9681                       2.0
# 9682                       2.0

# %%
df2.describe()
# Out:
#           Unnamed: 0      addr_lat      addr_lon  surrounding_stops  \
# count   30753.000000  30753.000000  30753.000000            30753.0
# mean   155951.320944     41.414726    -81.688527                0.0
# std     81511.027174      0.097076      0.162953                0.0
# min      9678.000000     41.214000    -81.981000                0.0
# 25%     84545.000000     41.345000    -81.831000                0.0
# 50%    162158.000000     41.391000    -81.676000                0.0
# 75%    235922.000000     41.494000    -81.529000                0.0
# max    287866.000000     41.651000    -81.425000                0.0
#
#        surrounding_stops_a_mile
# count              30753.000000
# mean                  14.824245
# std                   13.593606
# min                    1.000000
# 25%                    5.000000
# 50%                   11.000000
# 75%                   21.000000
# max                  129.000000

# %%
df2.to_csv('30k_still_missing_a_mile.csv', index = False)

# %% [markdown]
# #  Last missing data 30k collection from here

# %%
df2 = pd.read_csv('30k_still_missing_a_mile.csv')

# %%
plt.scatter(df2.addr_lon, df2.addr_lat)

# %%
df = df_stopsPlus.head(0)

# %%
search_range = 0.007225*3

for i in range(len(df2)):
    
    search_range = 0.007225*3
    df_temp = dataframe_of_close_stops(df2.loc[i, 'addr_lat'],df2.loc[i, 'addr_lon'],df_stopsPlus, search_range)
    if len(df_temp)<5:
        while len(df_temp)<5:
            search_range = search_range * 2
            df_temp = dataframe_of_close_stops(df2.loc[i, 'addr_lat'],df2.loc[i, 'addr_lon'],df_stopsPlus, search_range)
    
    df_temp = Add_distance_to_dataframe(df_temp,df2.loc[i, 'addr_lat'],df2.loc[i, 'addr_lon'] )
    df_temp = df_temp.sort_values("distance").head(5)
    df_temp['addr_lat']= df2.loc[i, 'addr_lat']
    df_temp['addr_lon']= df2.loc[i, 'addr_lon']
    df = pd.concat([df, df_temp])
    
    if i%1000 == 0:
        print(i)
# Out:
# //anaconda/lib/python3.4/site-packages/pandas/core/indexing.py:284: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# //anaconda/lib/python3.4/site-packages/pandas/core/indexing.py:461: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  addr_lat  addr_lon  close_stops  distance  \
# 8        4909          4909    41.378   -81.981          2.0  1.174544
# 7        4845          4845    41.378   -81.981          2.0  1.179986
# 5        4820          4820    41.378   -81.981          2.0  1.272501
# 2        4363          4363    41.378   -81.981          2.0  1.274660
# 0        4361          4361    41.378   -81.981          1.0  1.368448
#
#    location_type parent_station  stop_code  stop_desc stop_id   stop_lat  \
# 8            0.0            NaN        NaN        NaN   10197  41.391666
# 7            0.0            NaN        NaN        NaN   10015  41.391715
# 5            0.0            NaN        NaN        NaN   09983  41.392709
# 2            0.0            NaN        NaN        NaN   09033  41.392850
# 0            0.0            NaN        NaN        NaN   09031  41.390873
#
#     stop_lon                                  stop_name  stop_url  \
# ...

# %%
df.to_csv('last_missing_30x5.csv', index = False)

# %%
df = df.drop('Unnamed: 0.1', 1)

# %%
df = pd.read_csv('last_missing_30x5.csv')
# Out:
# //anaconda/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (5,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for i in range (len(df)):
     
    if np.isnan(df.loc[i, "walking_time"]):
        df.loc[i, "walking_time"] = getWalkingTime(df.loc[i,"stop_lat"],df.loc[i,"stop_lon"],df.loc[i,"addr_lat"],df.loc[i,"addr_lon"])
    
        if i%10000 == 0:
            num = str(int(i/1000))
            df.to_csv("last_30x5k_stop_addr_{}k.csv".format(num), index = False)



               
            
    if i%1000 == 0:
        print(i)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# ...

# %%
i = 0
df.loc[i, "walking_time"] = getWalkingTime(df.loc[i,"stop_lat"],df.loc[i,"stop_lon"],df.loc[i,"addr_lat"],df.loc[i,"addr_lon"])

# %%
df.to_csv('last_missing_30x5_stops.csv', index = False)

# %%
df.head()
# Out:
#    addr_lat  addr_lon  close_stops  distance  location_type parent_station  \
# 0    41.378   -81.981          2.0  1.174544            0.0            NaN
# 1    41.378   -81.981          2.0  1.179986            0.0            NaN
# 2    41.378   -81.981          2.0  1.272501            0.0            NaN
# 3    41.378   -81.981          2.0  1.274660            0.0            NaN
# 4    41.378   -81.981          1.0  1.368448            0.0            NaN
#
#    stop_code  stop_desc stop_id   stop_lat   stop_lon  \
# 0        NaN        NaN   10197  41.391666 -81.967530
# 1        NaN        NaN   10015  41.391715 -81.967442
# 2        NaN        NaN   09983  41.392709 -81.966235
# 3        NaN        NaN   09033  41.392850 -81.966416
# 4        NaN        NaN   09031  41.390873 -81.960973
#
#                                    stop_name  stop_url  total_bus_frequency  \
# 0  LORAIN RD & NORTH OLMSTED INDUSTRIAL PKWY       NaN                170.0
# ...

# %%
df.describe()
# Out:
#             addr_lat       addr_lon    close_stops       distance  \
# count  153765.000000  153765.000000  153765.000000  153765.000000
# mean       41.414726     -81.688527       1.414405       0.798840
# std         0.097075       0.162951       0.506370       0.226123
# min        41.214000     -81.981000       1.000000       0.374074
# 25%        41.345000     -81.831000       1.000000       0.631606
# 50%        41.391000     -81.676000       1.000000       0.766829
# 75%        41.494000     -81.529000       2.000000       0.938650
# max        41.651000     -81.425000       4.000000       2.251129
#
#        location_type  stop_code  stop_desc       stop_lat       stop_lon  \
# count  153765.000000        0.0        0.0  153765.000000  153765.000000
# mean        0.003987        NaN        NaN      41.414677     -81.688310
# std         0.063014        NaN        NaN       0.093572       0.160733
# min         0.000000        NaN        NaN      41.227883     -81.967530
# ...

# %% [markdown]
# #  concat

# %%
df_136k = pd.read_csv("missing_stop_136k.csv")
# Out:
# //anaconda/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_340k = pd.read_csv("052316_stop_addr_340k.csv")
# Out:
# //anaconda/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_153k = pd.read_csv('last_missing_30x5_stops.csv')
# Out:
# //anaconda/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (5,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_total = pd.concat([df_340k, df_136k, df_153k])

# %%
df_total.head()
# Out:
#    addr_lat  addr_lon  close_stops  distance  location_type parent_station  \
# 0    41.385   -81.974          2.0  0.569814            0.0            NaN
# 1    41.385   -81.974          2.0  0.575245            0.0            NaN
# 2    41.385   -81.974          2.0  0.667742            0.0            NaN
# 3    41.385   -81.974          2.0  0.669943            0.0            NaN
# 4    41.385   -81.974          1.0  0.789075            0.0            NaN
#
#    stop_code  stop_desc stop_id   stop_lat   stop_lon  \
# 0        NaN        NaN   10197  41.391666 -81.967530
# 1        NaN        NaN   10015  41.391715 -81.967442
# 2        NaN        NaN   09983  41.392709 -81.966235
# 3        NaN        NaN   09033  41.392850 -81.966416
# 4        NaN        NaN   09031  41.390873 -81.960973
#
#                                    stop_name  stop_url  total_bus_frequency  \
# 0  LORAIN RD & NORTH OLMSTED INDUSTRIAL PKWY       NaN                170.0
# ...

# %%
df_total = df_total.drop('Unnamed: 0.1',1)

# %%
df_total = df_total.sort_values(['addr_lat','addr_lon'])

# %%
df_total.to_csv("total_addr.csv", index = False)

# %%
plt.scatter(df_total.addr_lon, df_total.addr_lat, c = df_total.walking_time)
plt.xlim(-81.8,-81.75)
plt.ylim(41.4,41.45)
# Out:
# (41.4, 41.45)

# %%
plt.scatter(df_total.addr_lon, df_total.addr_lat)

# %% [markdown]
# #  Previous functions required here

# %%
from MapboxAPIWrapper import MapboxAPIWrapper
from MapLocation import MapLocation

wrapper = MapboxAPIWrapper()
wrapper.load_api_key_from_file("api_key.txt")

def getWalkingTime(origin_lat, origin_lon, destination_lat, destination_lon):
    # returns walking time in seconds
    origin = MapLocation(origin_lat, origin_lon)
    destination = MapLocation(destination_lat, destination_lon)
    results = wrapper.get_distance_from_api(origin, destination)
    return results["time"]

# %%
from geopy.distance import vincenty

# %%
def dataframe_of_close_stops(given_lat, given_lon, df, given_range=0.007225):
    selectedDf = df[(df.stop_lat > (given_lat - given_range)) \
                    & (df.stop_lat < (given_lat + given_range))\
                    &(df.stop_lon > (given_lon - given_range)) \
                    & (df.stop_lon < (given_lon + given_range))]
    return selectedDf

# %%
def Add_distance_to_dataframe(addr_df, destination_lat, destination_lon):
    addr_df.index = range(0, len(addr_df))
    for i in range(len(addr_df)):
        addr_df.loc[i, "distance"] = vincenty((destination_lat, destination_lon), (addr_df.loc[i, "stop_lat"], addr_df.loc[i,"stop_lon"])).miles
    return addr_df

# %%
def get_number_of_close_stops(given_lat, given_lon, df, given_range=0.007225):
    number = len(dataframe_of_close_stops(given_lat, given_lon, df, given_range))
    return number

# %% [markdown]
# #  new

# %%
df = pd.read_csv('distance_added_to_030116.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  address_latitude  address_longitude  \
# 0           0             0         41.427883             -81.66
# 1           1             1         41.427883             -81.66
# 2           2             2         41.427883             -81.66
# 3           3             3         41.427883             -81.66
# 4           4             4         41.427883             -81.66
#
#    stop_latitude  stop_longitude  distance  time  direct_distance  \
# 0      41.446877      -81.658588      2425  1748         0.214851
# 1      41.447112      -81.659555      2505  1806         0.196012
# 2      41.446992      -81.662701      2768  1996         0.268539
# 3      41.446953      -81.657015      2295  1654         0.282422
# 4      41.447113      -81.657469      2330  1680         0.261389
#
#    walking_distance_mile
# 0               0.459280
# 1               0.474432
# 2               0.524242
# 3               0.434659
# 4               0.441288

# %%
df_total.columns
# Out:
# Index(['addr_lat', 'addr_lon', 'close_stops', 'distance', 'location_type',
#        'parent_station', 'stop_code', 'stop_desc', 'stop_id', 'stop_lat',
#        'stop_lon', 'stop_name', 'stop_url', 'total_bus_frequency',
#        'walking_time', 'zone_id'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1  address_latitude  address_longitude  \
# count  131565.00000  131565.00000     131565.000000      131565.000000
# mean    65782.00000   65782.00000         41.478983         -81.579900
# std     37979.68842   37979.68842          0.029704           0.046505
# min         0.00000       0.00000         41.427883         -81.660000
# 25%     32891.00000   32891.00000         41.453083         -81.620400
# 50%     65782.00000   65782.00000         41.478983         -81.579900
# 75%     98673.00000   98673.00000         41.504883         -81.539400
# max    131564.00000  131564.00000         41.530083         -81.499800
#
#        stop_latitude  stop_longitude       distance           time  \
# count  131565.000000   131565.000000  131565.000000  131565.000000
# mean       41.479297      -81.579801     575.478387     415.137689
# std         0.029331        0.046520     535.155975     385.699205
# ...

# %% [markdown]
# df = df.rename(columns={'$a': 'a', '$b': 'b'})

# %%
df= df.rename(columns = {'address_latitude':'addr_lat','address_longitude':'addr_lon','stop_latitude':'stop_lat','stop_longitude':'stop_lon'})

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   addr_lat  addr_lon   stop_lat   stop_lon  \
# 0           0             0  41.427883    -81.66  41.446877 -81.658588
# 1           1             1  41.427883    -81.66  41.447112 -81.659555
# 2           2             2  41.427883    -81.66  41.446992 -81.662701
# 3           3             3  41.427883    -81.66  41.446953 -81.657015
# 4           4             4  41.427883    -81.66  41.447113 -81.657469
#
#    distance  time  direct_distance  walking_distance_mile
# 0      2425  1748         0.214851               0.459280
# 1      2505  1806         0.196012               0.474432
# 2      2768  1996         0.268539               0.524242
# 3      2295  1654         0.282422               0.434659
# 4      2330  1680         0.261389               0.441288

# %%
df= df.rename(columns = {'time':'walking_time','distance':'walking_distance'})

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   addr_lat  addr_lon   stop_lat   stop_lon  \
# 0           0             0  41.427883    -81.66  41.446877 -81.658588
# 1           1             1  41.427883    -81.66  41.447112 -81.659555
# 2           2             2  41.427883    -81.66  41.446992 -81.662701
# 3           3             3  41.427883    -81.66  41.446953 -81.657015
# 4           4             4  41.427883    -81.66  41.447113 -81.657469
#
#    walking_distance  walking_time  direct_distance  walking_distance_mile
# 0              2425          1748         0.214851               0.459280
# 1              2505          1806         0.196012               0.474432
# 2              2768          1996         0.268539               0.524242
# 3              2295          1654         0.282422               0.434659
# 4              2330          1680         0.261389               0.441288

# %%
df= df.rename(columns = {'direct_distance':'distance'})

# %%
df = df.drop('walking_distance_mile',1)

# %%
df = df.drop('Unnamed: 0',1)

# %%
df = df.drop('Unnamed: 0.1',1)

# %%
df = df.drop('walking_distance',1)

# %%
df.head()
# Out:
#     addr_lat  addr_lon   stop_lat   stop_lon  walking_time  distance
# 0  41.427883    -81.66  41.446877 -81.658588          1748  0.214851
# 1  41.427883    -81.66  41.447112 -81.659555          1806  0.196012
# 2  41.427883    -81.66  41.446992 -81.662701          1996  0.268539
# 3  41.427883    -81.66  41.446953 -81.657015          1654  0.282422
# 4  41.427883    -81.66  41.447113 -81.657469          1680  0.261389

# %%
df2 = pd.concat([df_total, df])

# %%
df2 = df2.sort_values(['addr_lat','addr_lon'])

# %%
df2.to_csv('all_data_combined.csv', index = False)

# %%
df = pd.read_csv('all_data_combined.csv')
# Out:
# //anaconda/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_group = df.groupby(['addr_lat','addr_lon'])

# %%
df_group = df_group.describe()

# %%
df_group.head()
# Out:
#                          close_stops  distance   stop_lat   stop_lon  \
# addr_lat addr_lon
# 41.214   -81.855  count          5.0  5.000000   5.000000   5.000000
#                   mean           1.0  1.693755  41.236063 -81.841162
#                   std            0.0  0.367888   0.006042   0.000205
#                   min            1.0  1.210069  41.227883 -81.841340
#                   25%            1.0  1.483600  41.232807 -81.841277
#
#                          total_bus_frequency  walking_time
# addr_lat addr_lon
# 41.214   -81.855  count             5.000000      5.000000
#                   mean              7.200000   2509.800000
#                   std               2.683282    484.185605
#                   min               6.000000   1853.000000
#                   25%               6.000000   2252.000000

# %%
df_group.to_csv('all_data_combined_grouped.csv')

# %%
df_group = pd.read_csv('all_data_combined_grouped.csv')

# %%
df_group.head()
# Out:
#    addr_lat  addr_lon Unnamed: 2  close_stops  distance   stop_lat   stop_lon  \
# 0    41.214   -81.855      count          5.0  5.000000   5.000000   5.000000
# 1    41.214   -81.855       mean          1.0  1.693755  41.236063 -81.841162
# 2    41.214   -81.855        std          0.0  0.367888   0.006042   0.000205
# 3    41.214   -81.855        min          1.0  1.210069  41.227883 -81.841340
# 4    41.214   -81.855        25%          1.0  1.483600  41.232807 -81.841277
#
#    total_bus_frequency  walking_time
# 0             5.000000      5.000000
# 1             7.200000   2509.800000
# 2             2.683282    484.185605
# 3             6.000000   1853.000000
# 4             6.000000   2252.000000

# %%
df_final= df_group[df_group['Unnamed: 2']=='min'][['addr_lat','addr_lon','walking_time']]

# %%
plt.scatter(df_final.addr_lon, df_final.addr_lon, c=df_final.walking_time, alpha =0.1)

# %%
plt.scatter(df_group.addr_lon, df_group.addr_lon)

# %%
plt.scatter(df.addr_lon, df.addr_lon)

# %%
df['close_stops']= np.nan

# %%
df.to_csv('cleaned_mat_data.csv', index = False)

# %%
df_total.head()
# Out:
#        addr_lat  addr_lon  close_stops  distance stop_id   stop_lat  \
# 27355    41.214   -81.855          1.0  1.210069   09742  41.227883
# 27356    41.214   -81.855          1.0  1.483600   09743  41.232807
# 27357    41.214   -81.855          1.0  1.714491   09744  41.236603
# 27358    41.214   -81.855          1.0  1.895614   09745  41.239410
# 27359    41.214   -81.855          1.0  2.165000   09746  41.243613
#
#         stop_lon                          stop_name  total_bus_frequency  \
# 27355 -81.840813         LAUREL SQUARE SHOPPING CTR                 12.0
# 27356 -81.841204        PEARL RD & OXFORD DR (FLAG)                  6.0
# 27357 -81.841340     PEARL RD & MANHATTAN AV (FLAG)                  6.0
# 27358 -81.841178        PEARL RD & CENTER RD (FLAG)                  6.0
# 27359 -81.841277  PEARL RD & SHENANDOAH PKWY (FLAG)                  6.0
#
#        walking_time
# 27355        1853.0
# 27356        2252.0
# 27357        2551.0
# 27358        2778.0
# ...

# %%
df_total = df_total.drop('zone_id',1)

# %%
df = df[df_total.columns]

# %%
df2 = pd.concat([df_total, df])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-734cbe3aad55> in <module>()
# ----> 1 df2 = pd.concat([df_total, df])
#
# //anaconda/lib/python3.4/site-packages/pandas/tools/merge.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     833                        verify_integrity=verify_integrity,
#     834                        copy=copy)
# --> 835     return op.get_result()
#     836
#     837
#
# //anaconda/lib/python3.4/site-packages/pandas/tools/merge.py in get_result(self)
#    1023             new_data = concatenate_block_managers(
#    1024                 mgrs_indexers, self.new_axes,
# -> 1025                 concat_axis=self.axis, copy=self.copy)
#    1026             if not self.copy:
#    1027                 new_data._consolidate_inplace()
#
# ...

# %%
df.head()
# Out:
#     addr_lat  addr_lon  close_stops  distance  stop_id   stop_lat   stop_lon  \
# 0  41.427883    -81.66          NaN  0.214851      NaN  41.446877 -81.658588
# 1  41.427883    -81.66          NaN  0.196012      NaN  41.447112 -81.659555
# 2  41.427883    -81.66          NaN  0.268539      NaN  41.446992 -81.662701
# 3  41.427883    -81.66          NaN  0.282422      NaN  41.446953 -81.657015
# 4  41.427883    -81.66          NaN  0.261389      NaN  41.447113 -81.657469
#
#    stop_name  total_bus_frequency  walking_time  walking_time
# 0        NaN                  NaN          2425          1748
# 1        NaN                  NaN          2505          1806
# 2        NaN                  NaN          2768          1996
# 3        NaN                  NaN          2295          1654
# 4        NaN                  NaN          2330          1680

# %%
df_total.head()
# Out:
#        addr_lat  addr_lon  close_stops  distance stop_id   stop_lat  \
# 27355    41.214   -81.855          1.0  1.210069   09742  41.227883
# 27356    41.214   -81.855          1.0  1.483600   09743  41.232807
# 27357    41.214   -81.855          1.0  1.714491   09744  41.236603
# 27358    41.214   -81.855          1.0  1.895614   09745  41.239410
# 27359    41.214   -81.855          1.0  2.165000   09746  41.243613
#
#         stop_lon                          stop_name  total_bus_frequency  \
# 27355 -81.840813         LAUREL SQUARE SHOPPING CTR                 12.0
# 27356 -81.841204        PEARL RD & OXFORD DR (FLAG)                  6.0
# 27357 -81.841340     PEARL RD & MANHATTAN AV (FLAG)                  6.0
# 27358 -81.841178        PEARL RD & CENTER RD (FLAG)                  6.0
# 27359 -81.841277  PEARL RD & SHENANDOAH PKWY (FLAG)                  6.0
#
#        walking_time
# 27355        1853.0
# 27356        2252.0
# 27357        2551.0
# 27358        2778.0
# ...
